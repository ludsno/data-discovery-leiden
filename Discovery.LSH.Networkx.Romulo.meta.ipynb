# %%
import time
s_t = time.strftime("%H:%M:%S", time.localtime())
start_time = time.perf_counter()
print(f"Program META (Data: Romulo) started at {s_t}")

#preparation
# %run Discovery.LSH.Networkx.Module.ipynb
directory = 'data\\romulo\\data-lakes\\clustering\\'
max_size = 1000000
encoding='ISO-8859-1'
sep = ","
fresh = False
# fresh = True
print(f'\n"fresh" set as "{fresh}".\n')
n_hash_fs=100
n_bands = 20
csv_infer, datasets, ini_nodes, init_edges, merge_nodes, merge_edges = prepare(directory, fresh, encoding=encoding, sep=sep, max_size=max_size, n_hash_fs=n_hash_fs, n_bands=n_bands)

#draw charts
max_metadata_length=100
untrained_model, trained_kfold_model, trained_shuffle_model, communities, community_labels, feature_vocab, X, y = \
draw_all(csv_infer, datasets, ini_nodes, init_edges, merge_nodes, merge_edges, encoding=encoding, sep=sep, max_metadata_length=max_metadata_length)

#redo metrics
random_state=50
train_kfold(community_labels, X, y)

test_size=0.75
random_state=100
train_shuffle(community_labels, X, y, test_size, random_state)

finish_time = time.perf_counter()
e_t = time.strftime("%H:%M:%S", time.localtime())
print(f"Program META (Data: Romulo) finished at {e_t} in {(finish_time-start_time)/60} minutes")
# Out:
# Program META (Data: Romulo) started at 17:26:40
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ludso\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# "fresh" set as "False".
#
# file datasets.pkl read successfully
# Function:get_zips() started at 17:26:50
# Function:get_zips() finished at 17:35:55 in 9.078590985000002 minutes
# Function:get_zips() started at 17:35:58
# Function:get_zips() finished at 17:35:58 in 0.003407993333333555 minutes
# Function:LSH-based Similarity started at 17:35:59
# Processing total datasets: 1248
# Function:LSH-based Similarity finished at 17:38:38 in 2.661413083333334 minutes
# largest_shape == 5090
# nbits == 2
# 1248 / 4 = 312.0, samples_buckets: 312.0, prev_samples_buckets:inf
# nbits == 4
# 1248 / 16 = 78.0, samples_buckets: 78.0, prev_samples_buckets:312.0
# nbits == 8
# 1248 / 256 = 4.875, samples_buckets: 4.875, prev_samples_buckets:78.0
# nbits == 16
# 1248 / 65536 = 0.01904296875, samples_buckets: 0.01904296875, prev_samples_buckets:4.875
# best_nbits == 8
# Number of nodes: 1248
# Number of edges: 776700
# Fold 1 - Accuracy: 0.94000, Precision: 0.94335, Recall: 0.94000, F1-Score: 0.94066
#
# Average Metrics Across Folds:
# Average Accuracy: 0.18800
# Average Precision: 0.18867
# Average Recall: 0.18800
# Average F1-Score: 0.18813
# Fold 2 - Accuracy: 0.95600, Precision: 0.95766, Recall: 0.95600, F1-Score: 0.95620
#
# Average Metrics Across Folds:
# Average Accuracy: 0.37920
# Average Precision: 0.38020
# Average Recall: 0.37920
# Average F1-Score: 0.37937
# Fold 3 - Accuracy: 0.95600, Precision: 0.95969, Recall: 0.95600, F1-Score: 0.95670
#
# Average Metrics Across Folds:
# Average Accuracy: 0.57040
# Average Precision: 0.57214
# Average Recall: 0.57040
# Average F1-Score: 0.57071
# Fold 4 - Accuracy: 0.89558, Precision: 0.90432, Recall: 0.89558, F1-Score: 0.89728
#
# Average Metrics Across Folds:
# Average Accuracy: 0.74952
# Average Precision: 0.75300
# Average Recall: 0.74952
# Average F1-Score: 0.75017
# Fold 5 - Accuracy: 0.94779, Precision: 0.94794, Recall: 0.94779, F1-Score: 0.94746
#
# Average Metrics Across Folds:
# Average Accuracy: 0.93907
# Average Precision: 0.94259
# Average Recall: 0.93907
# Average F1-Score: 0.93966
# Accuracy: 0.9333
# Precision: 0.9336
# Recall: 0.9333
# F1-Score: 0.9334
# Confusion Matrix:
# [[150   3   4   0   0   0   0]
#  [  4  93   2   2   0   0   0]
#  [  0   6  50   0   0   0   0]
#  [  3   0   1  36   0   0   0]
#  [  0   0   0   0  16   0   0]
#  [  0   0   0   0   0   4   0]
#  [  0   0   0   0   0   0   1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       157
#            1       0.91      0.92      0.92       101
#            2       0.88      0.89      0.88        56
#            3       0.95      0.90      0.92        40
#            4       1.00      1.00      1.00        16
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         1
#
#     accuracy                           0.93       375
#    macro avg       0.96      0.95      0.95       375
# weighted avg       0.93      0.93      0.93       375
#
# ROC AUC for Community 0: 0.9870
# ROC AUC for Community 1: 0.9724
# ROC AUC for Community 2: 0.9908
# ROC AUC for Community 3: 0.9973
# ROC AUC for Community 4: 1.0000
# ROC AUC for Community 5: 1.0000
# ROC AUC for Community 6: 1.0000
# Confusion Matrix:
# [[150   3   4   0   0   0   0]
#  [  4  93   2   2   0   0   0]
#  [  0   6  50   0   0   0   0]
#  [  3   0   1  36   0   0   0]
#  [  0   0   0   0  16   0   0]
#  [  0   0   0   0   0   4   0]
#  [  0   0   0   0   0   0   1]]
# Fold 1 - Accuracy: 0.94400, Precision: 0.94695, Recall: 0.94400, F1-Score: 0.94472
#
# Average Metrics Across Folds:
# Average Accuracy: 0.18880
# Average Precision: 0.18939
# Average Recall: 0.18880
# Average F1-Score: 0.18894
# Fold 2 - Accuracy: 0.95600, Precision: 0.95766, Recall: 0.95600, F1-Score: 0.95620
#
# Average Metrics Across Folds:
# Average Accuracy: 0.38000
# Average Precision: 0.38092
# Average Recall: 0.38000
# Average F1-Score: 0.38018
# Fold 3 - Accuracy: 0.95600, Precision: 0.95969, Recall: 0.95600, F1-Score: 0.95670
#
# Average Metrics Across Folds:
# Average Accuracy: 0.57120
# Average Precision: 0.57286
# Average Recall: 0.57120
# Average F1-Score: 0.57152
# Fold 4 - Accuracy: 0.89960, Precision: 0.90697, Recall: 0.89960, F1-Score: 0.90107
#
# Average Metrics Across Folds:
# Average Accuracy: 0.75112
# Average Precision: 0.75425
# Average Recall: 0.75112
# Average F1-Score: 0.75174
# Fold 5 - Accuracy: 0.94779, Precision: 0.94794, Recall: 0.94779, F1-Score: 0.94746
#
# Average Metrics Across Folds:
# Average Accuracy: 0.94068
# Average Precision: 0.94384
# Average Recall: 0.94068
# Average F1-Score: 0.94123
# Accuracy: 0.8622
# Precision: 0.8595
# Recall: 0.8622
# F1-Score: 0.8604
# Confusion Matrix:
# [[342  29  14   6   0   0   0]
#  [ 13 218  17   5   0   0   0]
#  [ 20   9 109   1   0   0   0]
#  [  4   0   1  94   0   0   0]
#  [  6   0   0   0  34   0   0]
#  [  0   0   0   0   0  10   0]
#  [  4   0   0   0   0   0   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       391
#            1       0.85      0.86      0.86       253
#            2       0.77      0.78      0.78       139
#            3       0.89      0.95      0.92        99
#            4       1.00      0.85      0.92        40
#            5       1.00      1.00      1.00        10
#            6       0.00      0.00      0.00         4
#
#     accuracy                           0.86       936
#    macro avg       0.77      0.76      0.76       936
# weighted avg       0.86      0.86      0.86       936
#
# ROC AUC for Community 0: 0.9650
# ROC AUC for Community 1: 0.9608
# ROC AUC for Community 2: 0.9641
# ROC AUC for Community 3: 0.9934
# ROC AUC for Community 4: 0.9988
# ROC AUC for Community 5: 1.0000
# ROC AUC for Community 6: 0.9989
# Confusion Matrix:
# [[342  29  14   6   0   0   0]
#  [ 13 218  17   5   0   0   0]
#  [ 20   9 109   1   0   0   0]
#  [  4   0   1  94   0   0   0]
#  [  6   0   0   0  34   0   0]
#  [  0   0   0   0   0  10   0]
#  [  4   0   0   0   0   0   0]]
# Program META (Data: Romulo) finished at 18:15:05 in 48.424159395 minutes
